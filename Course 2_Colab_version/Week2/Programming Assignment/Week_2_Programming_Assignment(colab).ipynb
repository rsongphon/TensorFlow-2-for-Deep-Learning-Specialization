# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Data pipeline with Keras and tf.data

# %% [markdown]
# ### Instructions
#
# In this notebook, you will implement a data processing pipeline using tools from both Keras and the tf.data module. You will use the `ImageDataGenerator` class in the tf.keras module to feed a network with training and test images from a local directory containing a subset of the LSUN dataset, and train the model both with and without data augmentation. You will then use the `map` and `filter` functions of the `Dataset` class with the CIFAR-100 dataset to train a network to classify a processed subset of the images.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from tensorflow.keras import Input,Model
from tensorflow.keras.layers import Dense , Flatten , Conv2D , MaxPool2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping , ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ### Part 1: tf.keras
#
# #### The LSUN Dataset
#
# In the first part of this assignment, you will use a subset of the [LSUN dataset](https://www.yf.io/p/lsun). This is a large-scale image dataset with 10 scene and 20 object categories. A subset of the LSUN dataset has been provided, and has already been split into training and test sets. The three classes included in the subset are `church_outdoor`, `classroom` and `conference_room`.
#
# * F. Yu, A. Seff, Y. Zhang, S. Song, T. Funkhouser and J. Xia. "LSUN: Construction of a Large-scale Image Dataset using Deep Learning with Humans in the Loop". arXiv:1506.03365, 10 Jun 2015
#
# Your goal is to use the Keras preprocessing tools to construct a data ingestion and augmentation pipeline to train a neural network to classify the images into the three classes.

# %% [markdown]
# #### Import the data
#
# The dataset is available for download as a zip file at the following link:
#
# https://drive.google.com/open?id=1T4jFYYLHSuG5zjo1dF3btCLzgS2R2AU-
#
# You should store the unzipped folder in Drive for use in this Colab notebook.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Save the directory locations for the training, validation and test sets
# Please replace the paths below with the appropriate paths in your drive

train_dir = '/content/gdrive/MyDrive/Tensorflow for deep learning Specialization/Course 2/Week2/Programming Assignment/colab_data/lsun/train'
valid_dir = '/content/gdrive/MyDrive/Tensorflow for deep learning Specialization/Course 2/Week2/Programming Assignment/colab_data/lsun/valid'
test_dir = '/content/gdrive/MyDrive/Tensorflow for deep learning Specialization/Course 2/Week2/Programming Assignment/colab_data/lsun/test'

# %% [markdown]
# #### Create a data generator using the ImageDataGenerator class

# %% [markdown]
# You should first write a function that creates an `ImageDataGenerator` object, which rescales the image pixel values by a factor of 1/255.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator():
    """
    This function should return an instance of the ImageDataGenerator class.
    This instance should be set up to rescale the data with the above scaling factor.
    """
    image_generator = ImageDataGenerator(
                      rescale = (1/255.)
    )
    
    return image_generator

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen = get_ImageDataGenerator()

# %% [markdown]
# You should now write a function that returns a generator object that will yield batches of images and labels from the training and test set directories. The generators should:
#
# * Generate batches of size 20.
# * Resize the images to 64 x 64 x 3.
# * Return one-hot vectors for labels. These should be encoded as follows:
#     * `classroom` $\rightarrow$ `[1., 0., 0.]`
#     * `conference_room` $\rightarrow$ `[0., 1., 0.]`
#     * `church_outdoor` $\rightarrow$ `[0., 0., 1.]`
# * Pass in an optional random `seed` for shuffling (this should be passed into the `flow_from_directory` method).
#
# **Hint:** you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_generator(image_data_generator, directory, seed=None):
    """
    This function takes an ImageDataGenerator object in the first argument and a 
    directory path in the second argument.
    It should use the ImageDataGenerator to return a generator object according 
    to the above specifications. 
    The seed argument should be passed to the flow_from_directory method.
    """
    # ฟังก์ชั่นเพื่อสร้าง generator 
    # ใช้ flow_from_directory เรียกจากโฟลเดอร์
    # directory ข้างในต้องแบ่งโฟลเดอร์ตาม class
    generator = image_data_generator.flow_from_directory(directory,
                                                         target_size=(64, 64),
                                                         color_mode='rgb', # 3 channel
                                                         # การระบุ class ใน list ชื่อจะต้องตามโฟลเดอร์จริง (ถ้าพิมพ์ผิดหรือไม่มีก็จะข้ามไป)
                                                         # ถ้าไม่ระบุ keras automatically inferred from the subdirectory names/structure 
                                                         # ถ้าเรากำหนด classes แบบ manual ด้วย argument นี้ เราสามารถเลือกได้ว่าจะเอาโฟลเดอร์ไหนบ้าง
                                                         # และเมื่อเอามาเรียงตาม list index จะ one hot ตามorder
                                                        classes = ['classroom','conference_room','church_outdoor'],
                                                        class_mode = 'categorical', # "categorical" will be 2D one-hot encoded labels,
                                                        seed=seed,
                                                        batch_size = 20
                                                        )
    
    return generator

# %%
# Run this cell to define training and validation generators

train_generator = get_generator(image_gen, train_dir)
valid_generator = get_generator(image_gen, valid_dir)
# Out:
# Found 300 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %% [markdown]
# We are using a small subset of the dataset for demonstrative purposes in this assignment.

# %% [markdown]
# #### Display sample images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.

# %%
# Display a few images and labels from the training set

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])
lsun_classes = ['classroom', 'conference_room', 'church_outdoor']

plt.figure(figsize=(16,10))
for i in range(20):
    ax = plt.subplot(4, 5, i+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the training generator

train_generator = get_generator(image_gen, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Build the neural network model
#
# You will now build and compile a convolutional neural network classifier. Using the functional API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to define the Input layer.
# * The first hidden layer should be a Conv2D layer with 8 filters, a 8x8 kernel size.
# * The second hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * The third hidden layer should be a Conv2D layer with 4 filters, a 4x4 kernel size.
# * The fourth hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * This should be followed by a Flatten layer, and then a Dense layer with 16 units and ReLU activation.
# * The final layer should be a Dense layer with 3 units and softmax activation.
# * All Conv2D layers should use `"SAME"` padding and a ReLU activation function.
#
# In total, the network should have 8 layers. The model should then be compiled with the Adam optimizer with learning rate 0.0005, categorical cross entropy loss, and categorical accuracy metric.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_model(input_shape):
    """
    This function should build and compile a CNN model according to the above specification,
    using the functional API. Your function should return the model.
    """
    inputs = Input(shape = input_shape)
    x = Conv2D(8,(8,8),padding='SAME',activation='relu')(inputs)
    x = MaxPool2D((2,2))(x)
    x = Conv2D(4,(4,4),padding='SAME',activation='relu')(x)
    x = MaxPool2D((2,2))(x)
    x = Flatten()(x)
    x = Dense(16,activation='relu')(x)
    outputs  = Dense(3,activation='softmax')(x)

    model = Model(inputs = inputs , outputs = outputs)

    opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
    loss = tf.keras.losses.CategoricalCrossentropy()
    metrics = [tf.keras.metrics.CategoricalAccuracy()]

    model.compile(optimizer=opt , loss = loss , metrics = metrics)

    return model

# %%
# Build and compile the model, print the model summary

lsun_model = get_model((64, 64, 3))
lsun_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 8)         1544
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 4)         516
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 4)        0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 16)                16400
#
#  dense_1 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the neural network model
#
# You should now write a function to train the model for a specified number of epochs (specified in the `epochs` argument). The function takes a `model` argument, as well as `train_gen` and `valid_gen` arguments for the training and validation generators respectively, which you should use for training and validation data in the training run. You should also use the following callbacks:
#
# * An `EarlyStopping` callback that monitors the validation accuracy and has patience set to 10.
# * A `ReduceLROnPlateau` callback that monitors the validation loss and has the factor set to 0.5 and minimum learning set to 0.0001
#
# Your function should return the training history.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def train_model(model, train_gen, valid_gen, epochs):
    """
    This function should define the callback objects specified above, and then use the
    train_gen and valid_gen generator object arguments to train the model for the (maximum) 
    number of epochs specified in the function argument, using the defined callbacks.
    The function should return the training history.
    """
    
    # Create callback object
    earlystop = EarlyStopping(monitor='val_accuracy', patience=10)
    reduceop = ReduceLROnPlateau(monitor='val_loss',factor=0.5,min_delta=0.0001)
    callbacks = [earlystop,reduceop]
    # train generator
    #  model.fit_generator จะถูกลบออกในเวอร์ชั่นอนาคต model.fit จะ support generator
    history = model.fit_generator(train_gen ,validation_data = valid_gen , epochs = epochs , callbacks = callbacks)

    return history

# %%
# Train the model for (maximum) 50 epochs

history = train_model(lsun_model, train_generator, valid_generator, epochs=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 15/15 [==============================] - 196s 13s/step - loss: 1.1095 - categorical_accuracy: 0.3200 - val_loss: 1.0962 - val_categorical_accuracy: 0.3250
# Epoch 2/50
# 15/15 [==============================] - 2s 112ms/step - loss: 1.0895 - categorical_accuracy: 0.3733 - val_loss: 1.0895 - val_categorical_accuracy: 0.3833
# Epoch 3/50
# 15/15 [==============================] - 2s 113ms/step - loss: 1.0739 - categorical_accuracy: 0.4100 - val_loss: 1.0719 - val_categorical_accuracy: 0.3667
# Epoch 4/50
# 15/15 [==============================] - 2s 112ms/step - loss: 1.0538 - categorical_accuracy: 0.4200 - val_loss: 1.0519 - val_categorical_accuracy: 0.4250
# Epoch 5/50
# 15/15 [==============================] - 2s 111ms/step - loss: 1.0099 - categorical_accuracy: 0.5033 - val_loss: 0.9839 - val_categorical_accuracy: 0.5083
# Epoch 6/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.9175 - categorical_accuracy: 0.5967 - val_loss: 0.9183 - val_categorical_accuracy: 0.5333
# Epoch 7/50
# 15/15 [==============================] - 2s 103ms/step - loss: 0.8252 - categorical_accuracy: 0.6300 - val_loss: 0.7908 - val_categorical_accuracy: 0.7000
# Epoch 8/50
# 15/15 [==============================] - 2s 106ms/step - loss: 0.7755 - categorical_accuracy: 0.6133 - val_loss: 0.7627 - val_categorical_accuracy: 0.7083
# Epoch 9/50
# 15/15 [==============================] - 2s 106ms/step - loss: 0.6610 - categorical_accuracy: 0.7300 - val_loss: 0.7456 - val_categorical_accuracy: 0.6833
# Epoch 10/50
# 15/15 [==============================] - 2s 115ms/step - loss: 0.6194 - categorical_accuracy: 0.7800 - val_loss: 0.8010 - val_categorical_accuracy: 0.6667
# Epoch 11/50
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5959 - categorical_accuracy: 0.7400 - val_loss: 0.7415 - val_categorical_accuracy: 0.7000
# Epoch 12/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5927 - categorical_accuracy: 0.7500 - val_loss: 0.7666 - val_categorical_accuracy: 0.6583
# Epoch 13/50
# 15/15 [==============================] - 2s 113ms/step - loss: 0.5584 - categorical_accuracy: 0.7667 - val_loss: 0.7506 - val_categorical_accuracy: 0.6667
# Epoch 14/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.5496 - categorical_accuracy: 0.7600 - val_loss: 0.7623 - val_categorical_accuracy: 0.6583
# Epoch 15/50
# 15/15 [==============================] - 2s 113ms/step - loss: 0.5242 - categorical_accuracy: 0.7900 - val_loss: 0.7431 - val_categorical_accuracy: 0.6750
# Epoch 16/50
# 15/15 [==============================] - 2s 116ms/step - loss: 0.4784 - categorical_accuracy: 0.8100 - val_loss: 0.7678 - val_categorical_accuracy: 0.6583
# Epoch 17/50
# 15/15 [==============================] - 2s 116ms/step - loss: 0.4806 - categorical_accuracy: 0.7900 - val_loss: 0.7740 - val_categorical_accuracy: 0.6750
# Epoch 18/50
# 15/15 [==============================] - 2s 115ms/step - loss: 0.4703 - categorical_accuracy: 0.8000 - val_loss: 0.7574 - val_categorical_accuracy: 0.6833
# Epoch 19/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4369 - categorical_accuracy: 0.8300 - val_loss: 0.7894 - val_categorical_accuracy: 0.6333
# Epoch 20/50
# 15/15 [==============================] - 2s 107ms/step - loss: 0.4197 - categorical_accuracy: 0.8567 - val_loss: 0.7790 - val_categorical_accuracy: 0.6667
# Epoch 21/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.3967 - categorical_accuracy: 0.8533 - val_loss: 0.8336 - val_categorical_accuracy: 0.6500
# Epoch 22/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.3878 - categorical_accuracy: 0.8533 - val_loss: 0.8115 - val_categorical_accuracy: 0.6167
# Epoch 23/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4535 - categorical_accuracy: 0.8167 - val_loss: 0.9488 - val_categorical_accuracy: 0.5833
# Epoch 24/50
# 15/15 [==============================] - 2s 118ms/step - loss: 0.3931 - categorical_accuracy: 0.8600 - val_loss: 0.7868 - val_categorical_accuracy: 0.6667
# Epoch 25/50
# 15/15 [==============================] - 2s 105ms/step - loss: 0.3587 - categorical_accuracy: 0.8800 - val_loss: 0.8364 - val_categorical_accuracy: 0.6500
# Epoch 26/50
# 15/15 [==============================] - 2s 107ms/step - loss: 0.3276 - categorical_accuracy: 0.8967 - val_loss: 0.8169 - val_categorical_accuracy: 0.6583
# Epoch 27/50
# 15/15 [==============================] - 2s 104ms/step - loss: 0.3267 - categorical_accuracy: 0.8967 - val_loss: 0.8546 - val_categorical_accuracy: 0.6333
# Epoch 28/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.3046 - categorical_accuracy: 0.8967 - val_loss: 0.8835 - val_categorical_accuracy: 0.6500
# Epoch 29/50
# 15/15 [==============================] - 2s 112ms/step - loss: 0.2868 - categorical_accuracy: 0.9133 - val_loss: 0.8884 - val_categorical_accuracy: 0.6250
# Epoch 30/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.2967 - categorical_accuracy: 0.8967 - val_loss: 0.8727 - val_categorical_accuracy: 0.6333
# Epoch 31/50
# 15/15 [==============================] - 2s 112ms/step - loss: 0.2945 - categorical_accuracy: 0.9033 - val_loss: 0.9705 - val_categorical_accuracy: 0.6333
# Epoch 32/50
# 15/15 [==============================] - 2s 106ms/step - loss: 0.3044 - categorical_accuracy: 0.8767 - val_loss: 0.8966 - val_categorical_accuracy: 0.6750
# Epoch 33/50
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2544 - categorical_accuracy: 0.9267 - val_loss: 1.0472 - val_categorical_accuracy: 0.6250
# Epoch 34/50
# 15/15 [==============================] - 2s 108ms/step - loss: 0.2895 - categorical_accuracy: 0.8967 - val_loss: 0.9919 - val_categorical_accuracy: 0.6250
# Epoch 35/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.2418 - categorical_accuracy: 0.9133 - val_loss: 0.9322 - val_categorical_accuracy: 0.6250
# Epoch 36/50
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2094 - categorical_accuracy: 0.9400 - val_loss: 0.9733 - val_categorical_accuracy: 0.6250
# Epoch 37/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.1958 - categorical_accuracy: 0.9433 - val_loss: 0.9806 - val_categorical_accuracy: 0.6500
# Epoch 38/50
# 15/15 [==============================] - 2s 113ms/step - loss: 0.1844 - categorical_accuracy: 0.9567 - val_loss: 1.0280 - val_categorical_accuracy: 0.6250
# Epoch 39/50
# 15/15 [==============================] - 2s 108ms/step - loss: 0.1750 - categorical_accuracy: 0.9533 - val_loss: 1.0150 - val_categorical_accuracy: 0.6417
# Epoch 40/50
# 15/15 [==============================] - 2s 114ms/step - loss: 0.1633 - categorical_accuracy: 0.9567 - val_loss: 1.0781 - val_categorical_accuracy: 0.6083
# Epoch 41/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1625 - categorical_accuracy: 0.9567 - val_loss: 1.1022 - val_categorical_accuracy: 0.6250
# Epoch 42/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.1529 - categorical_accuracy: 0.9600 - val_loss: 1.0744 - val_categorical_accuracy: 0.6417
# Epoch 43/50
# 15/15 [==============================] - 2s 108ms/step - loss: 0.1515 - categorical_accuracy: 0.9733 - val_loss: 1.0809 - val_categorical_accuracy: 0.6500
# Epoch 44/50
# 15/15 [==============================] - 2s 111ms/step - loss: 0.1506 - categorical_accuracy: 0.9600 - val_loss: 1.1054 - val_categorical_accuracy: 0.6500
# Epoch 45/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1689 - categorical_accuracy: 0.9533 - val_loss: 1.1390 - val_categorical_accuracy: 0.6417
# Epoch 46/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.1292 - categorical_accuracy: 0.9700 - val_loss: 1.1431 - val_categorical_accuracy: 0.6333
# Epoch 47/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1096 - categorical_accuracy: 0.9767 - val_loss: 1.1796 - val_categorical_accuracy: 0.6333
# Epoch 48/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1071 - categorical_accuracy: 0.9767 - val_loss: 1.2152 - val_categorical_accuracy: 0.6417
# Epoch 49/50
# 15/15 [==============================] - 2s 109ms/step - loss: 0.0979 - categorical_accuracy: 0.9867 - val_loss: 1.2335 - val_categorical_accuracy: 0.6250
# Epoch 50/50
# 15/15 [==============================] - 2s 110ms/step - loss: 0.0898 - categorical_accuracy: 0.9900 - val_loss: 1.2927 - val_categorical_accuracy: 0.6250

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# You may notice overfitting in the above plots, through a growing discrepancy between the training and validation loss and accuracy. We will aim to mitigate this using data augmentation. Given our limited dataset, we may be able to improve the performance by applying random modifications to the images in the training data, effectively increasing the size of the dataset.

# %% [markdown]
# #### Create a new data generator with data augmentation
#
# You should now write a function to create a new `ImageDataGenerator` object, which performs the following data preprocessing and augmentation:
#
# * Scales the image pixel values by a factor of 1/255.
# * Randomly rotates images by up to 30 degrees
# * Randomly alters the brightness (picks a brightness shift value) from the range (0.5, 1.5)
# * Randomly flips images horizontally
#
# Hint: you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator_augmented():
    """
    This function should return an instance of the ImageDataGenerator class 
    with the above specifications.
    """

    image_generator = ImageDataGenerator(
                      rescale = (1/255.),
                      rotation_range = 30,
                      brightness_range = (0.5,1.5),
                      horizontal_flip = True
                      )
    
    return image_generator

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen_aug = get_ImageDataGenerator_augmented()

# %%
# Run this cell to define training and validation generators 

valid_generator_aug = get_generator(image_gen_aug, valid_dir)
train_generator_aug = get_generator(image_gen_aug, train_dir, seed=10)
# Out:
# Found 120 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
# Reset the original train_generator with the same random seed

train_generator = get_generator(image_gen, train_dir, seed=10)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Display sample augmented images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.
#
# The cell will display augmented and non-augmented images (and labels) from the training dataset, using the `train_generator_aug` and `train_generator` objects defined above (if the images do not correspond to each other, check you have implemented the `seed` argument correctly).

# %%
# Display a few images and labels from the non-augmented and augmented generators

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])

aug_batch = next(train_generator_aug)
aug_batch_images = np.array(aug_batch[0])
aug_batch_labels = np.array(aug_batch[1])

plt.figure(figsize=(16,5))
plt.suptitle("Unaugmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')
plt.figure(figsize=(16,5))
plt.suptitle("Augmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(aug_batch_images[i])
    plt.title(lsun_classes[np.where(aug_batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the augmented data generator

train_generator_aug = get_generator(image_gen_aug, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Train a new model on the augmented dataset

# %%
# Build and compile a new model

lsun_new_model = get_model((64, 64, 3))

# %%
# Train the model

history_augmented = train_model(lsun_new_model, train_generator_aug, valid_generator_aug, epochs=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 15/15 [==============================] - 3s 176ms/step - loss: 1.0947 - categorical_accuracy: 0.3567 - val_loss: 1.0339 - val_categorical_accuracy: 0.5500
# Epoch 2/50
# 15/15 [==============================] - 2s 154ms/step - loss: 1.0274 - categorical_accuracy: 0.5267 - val_loss: 0.9883 - val_categorical_accuracy: 0.5417
# Epoch 3/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.9551 - categorical_accuracy: 0.5467 - val_loss: 0.8897 - val_categorical_accuracy: 0.6583
# Epoch 4/50
# 15/15 [==============================] - 2s 159ms/step - loss: 0.9073 - categorical_accuracy: 0.5967 - val_loss: 0.8502 - val_categorical_accuracy: 0.6333
# Epoch 5/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.8303 - categorical_accuracy: 0.6233 - val_loss: 0.9880 - val_categorical_accuracy: 0.5167
# Epoch 6/50
# 15/15 [==============================] - 2s 153ms/step - loss: 0.8146 - categorical_accuracy: 0.6267 - val_loss: 0.7911 - val_categorical_accuracy: 0.6333
# Epoch 7/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.7604 - categorical_accuracy: 0.6567 - val_loss: 0.8062 - val_categorical_accuracy: 0.6333
# Epoch 8/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.7517 - categorical_accuracy: 0.6667 - val_loss: 0.8696 - val_categorical_accuracy: 0.5750
# Epoch 9/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.8234 - categorical_accuracy: 0.6067 - val_loss: 0.7600 - val_categorical_accuracy: 0.6500
# Epoch 10/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.7512 - categorical_accuracy: 0.6700 - val_loss: 0.7576 - val_categorical_accuracy: 0.6417
# Epoch 11/50
# 15/15 [==============================] - 2s 154ms/step - loss: 0.7220 - categorical_accuracy: 0.6767 - val_loss: 0.7212 - val_categorical_accuracy: 0.7167
# Epoch 12/50
# 15/15 [==============================] - 2s 151ms/step - loss: 0.6977 - categorical_accuracy: 0.6967 - val_loss: 0.7940 - val_categorical_accuracy: 0.7000
# Epoch 13/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.7196 - categorical_accuracy: 0.6667 - val_loss: 0.7663 - val_categorical_accuracy: 0.6833
# Epoch 14/50
# 15/15 [==============================] - 2s 151ms/step - loss: 0.6506 - categorical_accuracy: 0.7167 - val_loss: 0.7137 - val_categorical_accuracy: 0.6833
# Epoch 15/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.6677 - categorical_accuracy: 0.7067 - val_loss: 0.7449 - val_categorical_accuracy: 0.6667
# Epoch 16/50
# 15/15 [==============================] - 2s 157ms/step - loss: 0.6624 - categorical_accuracy: 0.6967 - val_loss: 0.7562 - val_categorical_accuracy: 0.7333
# Epoch 17/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.6793 - categorical_accuracy: 0.6933 - val_loss: 0.8294 - val_categorical_accuracy: 0.6583
# Epoch 18/50
# 15/15 [==============================] - 2s 158ms/step - loss: 0.7045 - categorical_accuracy: 0.7100 - val_loss: 0.7237 - val_categorical_accuracy: 0.6500
# Epoch 19/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.6405 - categorical_accuracy: 0.7267 - val_loss: 0.7436 - val_categorical_accuracy: 0.7083
# Epoch 20/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.6434 - categorical_accuracy: 0.7400 - val_loss: 0.7584 - val_categorical_accuracy: 0.6917
# Epoch 21/50
# 15/15 [==============================] - 2s 153ms/step - loss: 0.6186 - categorical_accuracy: 0.7367 - val_loss: 0.7771 - val_categorical_accuracy: 0.6750
# Epoch 22/50
# 15/15 [==============================] - 2s 153ms/step - loss: 0.6542 - categorical_accuracy: 0.7067 - val_loss: 0.7977 - val_categorical_accuracy: 0.6750
# Epoch 23/50
# 15/15 [==============================] - 2s 158ms/step - loss: 0.6165 - categorical_accuracy: 0.7700 - val_loss: 0.7399 - val_categorical_accuracy: 0.6667
# Epoch 24/50
# 15/15 [==============================] - 2s 154ms/step - loss: 0.6443 - categorical_accuracy: 0.7167 - val_loss: 0.7623 - val_categorical_accuracy: 0.7167
# Epoch 25/50
# 15/15 [==============================] - 2s 149ms/step - loss: 0.6748 - categorical_accuracy: 0.7033 - val_loss: 0.7032 - val_categorical_accuracy: 0.7250
# Epoch 26/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.5962 - categorical_accuracy: 0.7233 - val_loss: 0.6794 - val_categorical_accuracy: 0.7167
# Epoch 27/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5961 - categorical_accuracy: 0.7367 - val_loss: 0.7498 - val_categorical_accuracy: 0.7000
# Epoch 28/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.5824 - categorical_accuracy: 0.7633 - val_loss: 0.8561 - val_categorical_accuracy: 0.6750
# Epoch 29/50
# 15/15 [==============================] - 2s 151ms/step - loss: 0.5671 - categorical_accuracy: 0.7667 - val_loss: 0.7723 - val_categorical_accuracy: 0.6750
# Epoch 30/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5870 - categorical_accuracy: 0.7167 - val_loss: 0.7491 - val_categorical_accuracy: 0.6833
# Epoch 31/50
# 15/15 [==============================] - 2s 158ms/step - loss: 0.5456 - categorical_accuracy: 0.7900 - val_loss: 0.7617 - val_categorical_accuracy: 0.6833
# Epoch 32/50
# 15/15 [==============================] - 2s 154ms/step - loss: 0.5849 - categorical_accuracy: 0.7567 - val_loss: 0.6961 - val_categorical_accuracy: 0.6917
# Epoch 33/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.5847 - categorical_accuracy: 0.7533 - val_loss: 0.8063 - val_categorical_accuracy: 0.6583
# Epoch 34/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5590 - categorical_accuracy: 0.7733 - val_loss: 0.7516 - val_categorical_accuracy: 0.6833
# Epoch 35/50
# 15/15 [==============================] - 2s 151ms/step - loss: 0.5380 - categorical_accuracy: 0.7667 - val_loss: 0.7603 - val_categorical_accuracy: 0.6500
# Epoch 36/50
# 15/15 [==============================] - 2s 152ms/step - loss: 0.5365 - categorical_accuracy: 0.7600 - val_loss: 0.7883 - val_categorical_accuracy: 0.6667
# Epoch 37/50
# 15/15 [==============================] - 2s 159ms/step - loss: 0.5570 - categorical_accuracy: 0.7733 - val_loss: 0.7860 - val_categorical_accuracy: 0.6917
# Epoch 38/50
# 15/15 [==============================] - 2s 158ms/step - loss: 0.5445 - categorical_accuracy: 0.7767 - val_loss: 0.7416 - val_categorical_accuracy: 0.6750
# Epoch 39/50
# 15/15 [==============================] - 2s 157ms/step - loss: 0.5409 - categorical_accuracy: 0.7700 - val_loss: 0.7810 - val_categorical_accuracy: 0.6917
# Epoch 40/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5359 - categorical_accuracy: 0.7833 - val_loss: 0.7645 - val_categorical_accuracy: 0.6750
# Epoch 41/50
# 15/15 [==============================] - 2s 154ms/step - loss: 0.5303 - categorical_accuracy: 0.7767 - val_loss: 0.8584 - val_categorical_accuracy: 0.6833
# Epoch 42/50
# 15/15 [==============================] - 2s 153ms/step - loss: 0.5344 - categorical_accuracy: 0.7633 - val_loss: 0.7133 - val_categorical_accuracy: 0.7000
# Epoch 43/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5509 - categorical_accuracy: 0.7667 - val_loss: 0.6897 - val_categorical_accuracy: 0.7167
# Epoch 44/50
# 15/15 [==============================] - 2s 155ms/step - loss: 0.5439 - categorical_accuracy: 0.7567 - val_loss: 0.7138 - val_categorical_accuracy: 0.6917
# Epoch 45/50
# 15/15 [==============================] - 2s 150ms/step - loss: 0.5128 - categorical_accuracy: 0.8000 - val_loss: 0.7457 - val_categorical_accuracy: 0.6833
# Epoch 46/50
# 15/15 [==============================] - 2s 162ms/step - loss: 0.5188 - categorical_accuracy: 0.7700 - val_loss: 0.7703 - val_categorical_accuracy: 0.7167
# Epoch 47/50
# 15/15 [==============================] - 2s 160ms/step - loss: 0.5062 - categorical_accuracy: 0.7967 - val_loss: 0.7874 - val_categorical_accuracy: 0.7000
# Epoch 48/50
# 15/15 [==============================] - 2s 156ms/step - loss: 0.5369 - categorical_accuracy: 0.7767 - val_loss: 0.7403 - val_categorical_accuracy: 0.7333
# Epoch 49/50
# 15/15 [==============================] - 2s 157ms/step - loss: 0.5252 - categorical_accuracy: 0.7700 - val_loss: 0.8500 - val_categorical_accuracy: 0.6667
# Epoch 50/50
# 15/15 [==============================] - 2s 149ms/step - loss: 0.5139 - categorical_accuracy: 0.7800 - val_loss: 0.8446 - val_categorical_accuracy: 0.6583

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history_augmented.history['accuracy'])
    plt.plot(history_augmented.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history_augmented.history['acc'])
        plt.plot(history_augmented.history['val_acc'])
    except KeyError:
        plt.plot(history_augmented.history['categorical_accuracy'])
        plt.plot(history_augmented.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history_augmented.history['loss'])
plt.plot(history_augmented.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Do you see an improvement in the overfitting? This will of course vary based on your particular run and whether you have altered the hyperparameters.

# %% [markdown]
# #### Get predictions using the trained model

# %%
# Get model predictions for the first 3 batches of test data

num_batches = 3
seed = 25
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
predictions = lsun_new_model.predict_generator(test_generator, steps=num_batches)
# Out:
# Found 300 images belonging to 3 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.

# %%
# Run this cell to view randomly selected images and model predictions

# Get images and ground truth labels
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
batches = []
for i in range(num_batches):
    batches.append(next(test_generator))
    
batch_images = np.vstack([b[0] for b in batches])
batch_labels = np.concatenate([b[1].astype(np.int32) for b in batches])

# Randomly select images from the batch
inx = np.random.choice(predictions.shape[0], 4, replace=False)
print(inx)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for n, i in enumerate(inx):
    axes[n, 0].imshow(batch_images[i])
    axes[n, 0].get_xaxis().set_visible(False)
    axes[n, 0].get_yaxis().set_visible(False)
    axes[n, 0].text(30., -3.5, lsun_classes[np.where(batch_labels[i] == 1.)[0][0]], 
                    horizontalalignment='center')
    axes[n, 1].bar(np.arange(len(predictions[i])), predictions[i])
    axes[n, 1].set_xticks(np.arange(len(predictions[i])))
    axes[n, 1].set_xticklabels(lsun_classes)
    axes[n, 1].set_title(f"Categorical distribution. Model prediction: {lsun_classes[np.argmax(predictions[i])]}")
    
plt.show()
# Out:
# Found 300 images belonging to 3 classes.
# [26 14 27 55]

# %% [markdown]
# Congratulations! This completes the first part of the programming assignment using the tf.keras image data processing tools.

# %% [markdown]
# ### Part 2: tf.data
#
# ![CIFAR-100 overview image](data/cifar100/cifar100.png)
#
# #### The CIFAR-100 Dataset

# %% [markdown]
# In the second part of this assignment, you will use the [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). This image dataset has 100 classes with 500 training images and 100 test images per class.
#
# * A. Krizhevsky. "Learning Multiple Layers of Features from Tiny Images". April 2009
#
# Your goal is to use the tf.data module preprocessing tools to construct a data ingestion pipeline including filtering and function mapping over the dataset to train a neural network to classify the images.

# %% [markdown]
# #### Load the dataset

# %%
# Load the data, along with the labels

(train_data, train_labels), (test_data, test_labels) = cifar100.load_data(label_mode='fine')
with open('/content/gdrive/MyDrive/Tensorflow for deep learning Specialization/Course 2/Week2/Programming Assignment/colab_data/cifar100/cifar100_labels.json', 'r') as j:
    cifar_labels = json.load(j)

# %% [markdown]
# #### Display sample images and labels from the training set

# %%
# Display a few images and labels

plt.figure(figsize=(15,8))
inx = np.random.choice(train_data.shape[0], 32, replace=False)
for n, i in enumerate(inx):
    ax = plt.subplot(4, 8, n+1)
    plt.imshow(train_data[i])
    plt.title(cifar_labels[int(train_labels[i])])
    plt.axis('off')

# %% [markdown]
# #### Create Dataset objects for the train and test images
#
# You should now write a function to create a `tf.data.Dataset` object for each of the training and test images and labels. This function should take a numpy array of images in the first argument and a numpy array of labels in the second argument, and create a `Dataset` object.
#
# Your function should then return the `Dataset` object. Do not batch or shuffle the `Dataset` (this will be done later).

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def create_dataset(data, labels):
    """
    This function takes a numpy array batch of images in the first argument, and
    a corresponding array containing the labels in the second argument.
    The function should then create a tf.data.Dataset object with these inputs
    and outputs, and return it.
    """
    # numpy array ใช้ from_tensor_slices
    dataset = tf.data.Dataset.from_tensor_slices((data, labels))
    return dataset

# %%
# Run the below cell to convert the training and test data and labels into datasets

train_dataset = create_dataset(train_data, train_labels)
test_dataset = create_dataset(test_data, test_labels)

# %%
# Check the element_spec of your datasets

print(train_dataset.element_spec)
print(test_dataset.element_spec)
# Out:
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))

# %% [markdown]
# #### Filter the Dataset
#
# Write a function to filter the train and test datasets so that they only generate images that belong to a specified set of classes.
#
# The function should take a `Dataset` object in the first argument, and a list of integer class indices in the second argument. Inside your function you should define an auxiliary function that you will use with the `filter` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a boolean indicating if the label is one of the allowed classes.
#
# Your function should then return the filtered dataset.
#
# **Hint:** you may need to use the [`tf.equal`](https://www.tensorflow.org/api_docs/python/tf/math/equal), [`tf.cast`](https://www.tensorflow.org/api_docs/python/tf/dtypes/cast) and [`tf.math.reduce_any`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_any) functions in your auxiliary function.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def filter_classes(dataset, classes):
    """
    This function should filter the dataset by only retaining dataset elements whose
    label belongs to one of the integers in the classes list.
    The function should then return the filtered Dataset object.
    """

    # Your datasets should contain only classes in this list classes
    def filterclass(image , label):
      #function ที่ใช้กับ filter method ของ dataset รับ argument ตาม shape ของ elementspec (จะ passให้อัตโนมัติตอนเรียก method)
      # classes เป็น list ต้องทำเป็น tensorก่อน
      # และให้เป็น  dtype=tf.int64 เหมือนใน dataset
      classes_tensor = tf.constant(classes , dtype=tf.int64)

      # label จะมาในรูป ([class]) จะเอาไปเทียบ กับ classes_tensor element-wise และ return ออกมาเป็น boolean tensor
      # ตาม shape ของ  classes_tensor
      filter  = tf.math.equal(classes_tensor,label)

      # ถ้า label ของ dataset elementนี้ ตรงกับหนึ่งใน classes_tensor ก็ให้ เก็บ dataset นี้ไว้
      # tf.math.reduce_any จะคำนวน or operation เช่น
      # tf.Tensor([False False False False  True], shape=(5,), dtype=bool) >>>>> tf.Tensor(True, shape=(), dtype=bool)

      # และ return ค่า boolean เพื่อ filter element นั้นๆ (True/False)
      return tf.math.reduce_any(filter)


    # เรียกใช้ filter กับ dataset โดยใช้ method .filter(filter function) 

    return dataset.filter(filterclass) # pass filter function

# %%
# Run the below cell to filter the datasets using your function

cifar_classes = [0, 29, 99] # Your datasets should contain only classes in this list

train_dataset = filter_classes(train_dataset, cifar_classes)
test_dataset = filter_classes(test_dataset, cifar_classes)

# %% [markdown]
# #### Apply map functions to the Dataset
#
# You should now write two functions that use the `map` method to process the images and labels in the filtered dataset.
#
# The first function should one-hot encode the remaining labels so that we can train the network using a categorical cross entropy loss.
#
# The function should take a `Dataset` object as an argument. Inside your function you should define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the unmodified image in the first element, and a one-hot vector in the second element. The labels should be encoded according to the following:
#
# * Class 0 maps to `[1., 0., 0.]`
# * Class 29 maps to `[0., 1., 0.]`
# * Class 99 maps to `[0., 0., 1.]`
#
# Your function should then return the mapped dataset.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_labels(dataset):
    """
    This function should map over the dataset to convert the label to a 
    one-hot vector. The encoding should be done according to the above specification.
    The function should then return the mapped Dataset object.
    """
    def one_hot_label(image,label):
      #function ที่ใช้กับ map method ของ dataset รับ argument ตาม shape ของ elementspec (จะ passให้อัตโนมัติตอนเรียก method)

      # เนื่องจาก class indice ไม่ได้เป็น interger เรียงกันใช้ tf.one_hot ไม่ได้
      # hard code ตามโจทย์เอา
      # จากการ inspect shape ของ label next(iter(train_dataset)) มีสอง element
      # next(iter(train_dataset))[0] = image shape (32,32,3)
      # next(iter(train_dataset))[1] = label shape (1,)
      # next(iter(train_dataset))[1][0] = label shape () (ใช้ 0 เพราะมี 1 element)
      # label เป็น array rank 1 เอามาlogic operation จะ return = rank ของ label
      # แต่เนื่องจากมี 1 element python เลยไม่ error
      # เพื่อความชัวร์ฺ เอาให้เป็นrank 0 เท่ากัน

      # map function ต้อง  return a tuple of two elements คือ dataset element ที่เราทำ operation อะไรซักอย่าง
      # return unmodified image in the first element, and a one-hot vector in the second element. 
      # next(iter(train_dataset))[1][0]  = label[0]
      if label[0] == 0 : 
        return image , tf.constant([1., 0., 0.])
      elif label[0] == 29: 
        return image , tf.constant([0., 1., 0.])
      else:
        return image , tf.constant([0., 0., 1.])

    # map fuction
    return dataset.map(one_hot_label)

# %%
# Run the below cell to one-hot encode the training and test labels.

train_dataset = map_labels(train_dataset)
test_dataset = map_labels(test_dataset)

# %% [markdown]
# The second function should process the images according to the following specification:
#
# * Rescale the image pixel values by a factor of 1/255.
# * Convert the colour images (3 channels) to black and white images (single channel) by computing the average pixel value across all channels.
#
# The function should take a `Dataset` object as an argument. Inside your function you should again define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the processed image in the first element, and the unmodified label in the second argument.
#
# Your function should then return the mapped dataset.
#
# **Hint:** you may find it useful to use [`tf.reduce_mean`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_mean?version=stable) since the black and white image is the colour-average of the colour images. You can also use the `keepdims` keyword in `tf.reduce_mean` to retain the single colour channel.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_images(dataset):
    """
    This function should map over the dataset to process the image according to the 
    above specification. The function should then return the mapped Dataset object.
    """
    
    # concept map function ตามเดิม
    def image_preprocess(image,label):

      # normalize ค่า 
      # Returns an element-wise x * y
      image = image / 255

      # ทำให้ภาพเป็น grayscale ด้วยการหาค่า mean ข้าม 3 channel และลดให้เหลือ 1 channel
      # ต้อง keepdims = True เพราะจะได้ เหลือ rank 3 (32,32,1) เท่าเดิม จาก (32,32,3)
      # ไม่งั้นจะเหลือ rank 2 (32,32)
      image = tf.math.reduce_mean(image ,axis = 2 , keepdims = True)
      
      #  return a tuple of two elements, with the processed image in the first element, and the unmodified label in the second argument.
      return (image,label)
    
    # map process
    return dataset.map(image_preprocess)

# %%
# Run the below cell to apply your mapping function to the datasets

train_dataset_bw = map_images(train_dataset)
test_dataset_bw = map_images(test_dataset)

# %% [markdown]
# #### Display a batch of processed images

# %%
# Run this cell to view a selection of images before and after processing

plt.figure(figsize=(16,5))
plt.suptitle("Unprocessed images", fontsize=16)
for n, elem in enumerate(train_dataset.take(10)):
    images, labels = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels == 1.)[0][0]]])
    plt.imshow(np.squeeze(images), cmap='gray')
    plt.axis('off')
    
plt.figure(figsize=(16,5))
plt.suptitle("Processed images", fontsize=16)
for n, elem in enumerate(train_dataset_bw.take(10)):
    images_bw, labels_bw = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels_bw == 1.)[0][0]]])
    plt.imshow(np.squeeze(images_bw), cmap='gray')
    plt.axis('off')

# %% [markdown]
# We will now batch and shuffle the Dataset objects.

# %%
# Run the below cell to batch the training dataset and expand the final dimensinos

train_dataset_bw = train_dataset_bw.batch(10)
train_dataset_bw = train_dataset_bw.shuffle(100)

test_dataset_bw = test_dataset_bw.batch(10)
test_dataset_bw = test_dataset_bw.shuffle(100)

# %% [markdown]
# #### Train a neural network model
#
# Now we will train a model using the `Dataset` objects. We will use the model specification and function from the first part of this assignment, only modifying the size of the input images.

# %%
# Build and compile a new model with our original spec, using the new image size
    
cifar_model = get_model((32, 32, 1))

# %%
# Train the model for 15 epochs

history = cifar_model.fit(train_dataset_bw, validation_data=test_dataset_bw, epochs=15)
# Out:
# Epoch 1/15
# 150/150 [==============================] - 4s 13ms/step - loss: 1.0521 - categorical_accuracy: 0.4633 - val_loss: 0.9492 - val_categorical_accuracy: 0.5967
# Epoch 2/15
# 150/150 [==============================] - 3s 11ms/step - loss: 0.8905 - categorical_accuracy: 0.6007 - val_loss: 0.7974 - val_categorical_accuracy: 0.6800
# Epoch 3/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.7902 - categorical_accuracy: 0.6687 - val_loss: 0.7484 - val_categorical_accuracy: 0.6900
# Epoch 4/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.7241 - categorical_accuracy: 0.6807 - val_loss: 0.7172 - val_categorical_accuracy: 0.6900
# Epoch 5/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.6806 - categorical_accuracy: 0.7147 - val_loss: 0.6765 - val_categorical_accuracy: 0.7233
# Epoch 6/15
# 150/150 [==============================] - 3s 11ms/step - loss: 0.6284 - categorical_accuracy: 0.7520 - val_loss: 0.6633 - val_categorical_accuracy: 0.7433
# Epoch 7/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.6061 - categorical_accuracy: 0.7587 - val_loss: 0.6145 - val_categorical_accuracy: 0.7367
# Epoch 8/15
# 150/150 [==============================] - 3s 13ms/step - loss: 0.5672 - categorical_accuracy: 0.7753 - val_loss: 0.6006 - val_categorical_accuracy: 0.7533
# Epoch 9/15
# 150/150 [==============================] - 3s 11ms/step - loss: 0.5530 - categorical_accuracy: 0.7807 - val_loss: 0.6230 - val_categorical_accuracy: 0.7467
# Epoch 10/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.5171 - categorical_accuracy: 0.7953 - val_loss: 0.6067 - val_categorical_accuracy: 0.7533
# Epoch 11/15
# 150/150 [==============================] - 3s 11ms/step - loss: 0.4974 - categorical_accuracy: 0.8113 - val_loss: 0.5606 - val_categorical_accuracy: 0.7800
# Epoch 12/15
# 150/150 [==============================] - 3s 11ms/step - loss: 0.4748 - categorical_accuracy: 0.8227 - val_loss: 0.5359 - val_categorical_accuracy: 0.7900
# Epoch 13/15
# 150/150 [==============================] - 3s 13ms/step - loss: 0.4505 - categorical_accuracy: 0.8280 - val_loss: 0.5849 - val_categorical_accuracy: 0.7600
# Epoch 14/15
# 150/150 [==============================] - 3s 13ms/step - loss: 0.4422 - categorical_accuracy: 0.8293 - val_loss: 0.5185 - val_categorical_accuracy: 0.7967
# Epoch 15/15
# 150/150 [==============================] - 3s 12ms/step - loss: 0.4323 - categorical_accuracy: 0.8367 - val_loss: 0.5361 - val_categorical_accuracy: 0.7833

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Create an iterable from the batched test dataset

test_dataset = test_dataset.batch(10)
iter_test_dataset = iter(test_dataset)

# %%
# Display model predictions for a sample of test images

plt.figure(figsize=(15,8))
inx = np.random.choice(test_data.shape[0], 18, replace=False)
images, labels = next(iter_test_dataset)
probs = cifar_model(tf.reduce_mean(tf.cast(images, tf.float32), axis=-1, keepdims=True) / 255.)
preds = np.argmax(probs, axis=1)
for n in range(10):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(images[n])
    plt.title(cifar_labels[cifar_classes[np.where(labels[n].numpy() == 1.0)[0][0]]])
    plt.text(0, 35, "Model prediction: {}".format(cifar_labels[cifar_classes[preds[n]]]))
    plt.axis('off')

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn to develop models for sequential data.
